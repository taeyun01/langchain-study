# %%
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.text_splitter import CharacterTextSplitter # 

splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=50, # 이 속성은 문장이나 문단을 분할할 때 앞 조각 일부분을 가져옴 (맨 마지막 뒷 부분을 가져다 다음 조각 앞 부분에 넣어서 분할)
)

# CharacterTextSplitter는 separator기준으로 분할 (특정 문자열을 찾아 거기부터 분할)
splitter2 = CharacterTextSplitter(
    separator="\n", # 문단 기준으로 분할
    chunk_size=600, # 최대 글자개수 600인 문서로 나눔 (separator가 없으면 좀 더 커질수도 있고 작아질 수도 있음)
    chunk_overlap=100,
)

loader = UnstructuredFileLoader("./files/ai-agent.pdf")

print(loader.load_and_split(text_splitter=splitter2))

# 파이썬에서 함수를 사용해서 분할하는게 아닌 문장과 문단 구조를 유지하고 문서를 나눈 것
# Out:
# [Document(page_content='모두의\x00AI\x00케인의\x00LangGraph로\x00끝내는\x00멀티\x00AI\x00Agent\x00ft.\x00 5가지\x00Advanced\x00AI\x00agent\x00구축\x00프로젝트\n\x00안내.\n해당\x00교육\x00과정\x00소개서는\x00모든\x00강의\x00영상이\x00촬영하기\x00전\x00작성되었습니다. *\x00커리큘럼은\x00촬영\x00및\x00편집을\x00거치며\x00일부\x00변경될\x00수\x00있으나,\x00전반적인\x00강의\x00내용에는\x00변동이\x00없습니다.\x00 아래\x00각\x00오픈\x00일정에\x00따라\x00공개됩니다.\x00\n1차\x00:\x002024년\x0009월\x0019일 ● 2차\x00:\x002024년\x0010월\x0014일 ● 3차\x00:\x002024년\x0011월\x0011일 ● ● 전체\x00:\x002024년\x0012월\x0009일\n최근\x00수정일자\x002024년\x0008월\x0012일\nLife Changing Education\n강의정보\n강의장\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00온라인\x00강의\x00|\x00데스크탑,\x00노트북,\x00모바일\x00등\n수강\x00기간\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00평생\x00소장\n상세페이지\x00\x00\x00\x00\x00\x00\x00\x00https://fastcampus.co.kr/dev_online_aiagent', metadata={'source': './files/ai-agent.pdf'}), Document(page_content='수강\x00기간\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00평생\x00소장\n상세페이지\x00\x00\x00\x00\x00\x00\x00\x00https://fastcampus.co.kr/dev_online_aiagent\n강의시간\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0033시간\x00예정\x00(*\x00사전\x00판매\x00중인\x00강의는\x00시간이\x00변경될\x00수\x00있습니다.)\n문의\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00고객센터\n강의특징\n나만의 속도로\n낮이나\x00새벽이나\x00 내가\x00원하는\x00시간대에\x00나의\x00스케쥴대로\x00수강\n원하는\x00곳 어디서나\n시간을\x00쪼개\x00먼\x00거리를\x00오가며\x00 오프라인\x00강의장을\x00찾을\x00필요\x00없이\x00어디서든\x00수강\n무제한 복습\n무엇이든\x00반복적으로\x00학습해야\x00 내것이\x00되기에\x00이해가\x00안가는\x00구간\x00몇번이고\x00재생\nLife Changing Education\nCopyright ⓒ FAST CAMPUS Corp. All Rights Reserved.\n강의목표\n14가지\x00실습으로\x00역할에\x00맞는\x00모델\x00&\x00API\x00연결하는\x00법이\x00까다로운\x00LangGraph의\x00활용법을\x00 익힙니다.\n기존\x00상용\x00서비스를\x00분석하고\x00재구현하는\x00[\x00리버스\x00엔지니어링\x00]\x00기법으로\x00멀티\x00에이전트의\x00 복잡성을\x00이해하고\x00기초를\x00탄탄하게\x00다집니다.\nAgent에\x00논리구조를\x00만들기\x00위해\x00우리는\x00다른\x003가지\x00프로젝트를\x00통해\x00알맞은\x00용도와\x00도구를\x00 매칭하는\x00연습을\x00반복합니다.', metadata={'source': './files/ai-agent.pdf'}), Document(page_content='Agent에\x00논리구조를\x00만들기\x00위해\x00우리는\x00다른\x003가지\x00프로젝트를\x00통해\x00알맞은\x00용도와\x00도구를\x00 매칭하는\x00연습을\x00반복합니다.\n주제와\x00관련된\x00최신\x00뉴스\x00기사를\x00가져오고\x00설정한\x00테마와\x00목차에\x00따라\x00뉴스레터\x00본문을\x00 작성하고\x00편집하는\x00과정을\x00자동화합니다.\n강의요약\n입문자를\x00위한\x00AI\x00agent\x00의\x00개념부터\x00프레임워크\x00활용\x00실습,\x00복잡한\x00아키텍처\x00구축\x00실습을\x00 위한\x005가지\x00AI\x00에이전트\x00구축\x00프로젝트까지\x00모두\x00담긴\x00탄탄한\x00커리큘럼을\x00확인하세요.\n현재\x00상용화되고\x00있는\x00AI를\x00반대로\x00거슬러\x00올라가\x00보며,\x00복잡한\x00AI\x00시스템\x00설계의\x00노하우를\x00 직접\x00체득하는\x002가지\x00프로젝트\n알아서\x00오류를\x00해결하는\x00Agentic\x00Workflow를\x00구현할\x00수\x00있도록\x00아키텍처\x00설계부터\x00시작하는\x00 3가지\x00멀티\x00AI\x00에이전트\x00구축\x00실습\n사용자가\x00원하는\x00정보에\x00따라\x00다른\x00검색\x00API를\x00활용하여\x00정보를\x00끌어오는\x00Agent를\x00 구축합니다.\nLife Changing Education\nCopyright ⓒ FAST CAMPUS Corp. All Rights Reserved.\n강사\n케인\n과목', metadata={'source': './files/ai-agent.pdf'}), Document(page_content='Life Changing Education\nCopyright ⓒ FAST CAMPUS Corp. All Rights Reserved.\n강사\n케인\n과목\n모두의\x00AI\x00케인의\x00LangGraph로\x00끝내는\x00멀티\x00AI\x00 Agent\x00ft.\x005가지\x00Advanced\x00AI\x00agent\x00구축\x00 프로젝트\n약력\n-\n(현)\x00국내\x00IT\x00대기업\x00AI\x00Researcher Youtube\x00‘모두의AI’\x00채널\x00운영\x00중\nLife Changing Education\nCopyright ⓒ FAST CAMPUS Corp. All Rights Reserved.\nCURRICULUM\nCH01.\x00강의\x00소개\n01.\x00강의\x00소개\n01.\x00\nCH02.\x00에이전트의\x00개념\n01.\x00에이전트의\x00개념과\x00필요성\n02.\x00에이전트의\x00종류\x00-\x00단일\x00에이전트와\x00다중\x00에이전트\x00시스템\n에이전트란\x00 무엇인가?\nCH03.\x00에이전트\x00프레임워크\n01.\x00에이전트\x00구축을\x00위한\x00여러\x00프레임워크(CrewAI,\x00Autogen,\x00Langgraph)\nCH04.\x00RAG를\x00보완하는\x00에이전트\n01.\x00RAG\x00구현\x00측면에서\x00에이전트의\x00필요성\nCH05.\x00에이전트가\x00할\x00수\x00있는\x00것\n01.\x00에이전트로\x00만들\x00수\x0 ...
